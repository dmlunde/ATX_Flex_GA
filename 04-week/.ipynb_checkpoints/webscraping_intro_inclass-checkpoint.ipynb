# %% [markdown]
# ### Webscraping!

# %% [markdown]
# Webscraping is a powerful tool for getting your own data - it's important to follow the policies outlined at the `./robots.txt` extension

# %% [markdown]
# I.e. the scraping policy for [Open Table](https://www.opentable.com) is listed at [https://www.opentable.com/robots.txt](https://www.opentable.com/robots.txt). Your path reading skills will help you here!

# %%
## imports 
import pandas as pd 
from bs4 import BeautifulSoup
import requests 
from time import sleep # this is a courtesy to the server so you don't overload it
import matplotlib.pyplot as plt 


# %matplotlib inline

# %%
## let's scrape from austin chronicle 
url = 'https://www.austinchronicle.com/events/music/'

# %% [markdown]
# ### 1) First get the requests and content with:
# ``` python
# res = requests.get(url)
#
# ```

# %%
## code . Be a good web surfer and don't over request a server for too long
res = requests.get(url)

# %%
res.status_code
# Out:
# 200

# %%
res.content
# Out:
# b'\n\n\n\n\n\n\n\n<!DOCTYPE html>\n<html xmlns="https://www.w3.org/1999/xhtml" xmlns:fb="https://www.facebook.com/2008/fbml" lang="en-US">\n<head>\n  \n  <meta http-equiv="Content-Type" content="text/html; charset=utf-8">\n  <meta charset="UTF-8">\n  <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no">\n\n  <link rel="stylesheet" type="text/css" href="https://cloud.typography.com/7790492/668686/css/fonts.css" />\n\n  <script src="https://use.fontawesome.com/1a933a8ada.js"></script>\n\n  <link rel="stylesheet" type="text/css" href="/Styles/responsive/ac-style.css?v=2.9" />\n\n  <link rel="stylesheet" type="text/css" href="/Styles/responsive/ac-menu.css" />\n  <link rel="stylesheet" type="text/css" href="/Styles/responsive/magnific.css" />\n  \n  <link rel="stylesheet" type="text/css" href="/Styles/responsive/fluid.css?v=1.3" />\n  \n\n  <link rel="apple-touch-icon" sizes="57x57" href="/apple-icon-57x57.png?v=2">\n  <link rel="apple-touch-icon" sizes="60x60" href="/apple-icon-60x60.png?v=2">\n  <link rel="apple-touch-icon" sizes="72x72" href="/apple-icon-72x72.png?v=2">\n  <link rel="apple-touch-icon" sizes="76x76" href="/apple-icon-76x76.png?v=2">\n  <link rel="apple-touch-icon" sizes="114x114" href="/apple-icon-114x114.png?v=2">\n  <link rel="apple-touch-icon" sizes="120x120" href="/apple-icon-120x120.png?v=2">\n  <link rel="apple-touch-icon" sizes="144x144" href="/apple-icon-144x144.png?v=2">\n  <link rel="apple-touch-icon" sizes="152x152" href="/apple-icon-152x152.png?v=2">\n  <link rel="apple-touch-icon" sizes="180x180" href="/apple-icon-180x180.png?v=2">\n  <link rel="icon" type="image/png" sizes="192x192"  href="/android-icon-192x192.png?v=2">\n  <link rel="icon" type="image/png" sizes="32x32" href="/favicon-32x32.png?v=2">\n  <link rel="icon" type="image/png" sizes="96x96" href="/favicon-96x96.png?v=2">\n  <link rel="icon" type="image/png" sizes="16x16" href="/favicon-16x16.png?v=2">\n  <link rel="shortcut icon" href="/favicon.ico?v=2">\n  \n  \n  <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.11.0/jquery.min.js"></script>\n  \n  \n  <script src="/Scripts/responsive/ac-custom.js"></script>\n  <script src="/Scripts/responsive/jquery.mmenu.min.js"></script>\n  <script src="/Scripts/responsive/jquery.autoellipsis-1.0.10.min.js"></script>\n  <script src="/Scripts/responsive/jquery.magnific.min.js"></script>\n  <script>!function(d,s,id){var js,fjs=d.getElementsByTagName(s)[0],p=/^http:/.test(d.location)?\'http\':\'https\';if(!d.getElementById(id)){js=d.createElement(s);js.id=id;js.src=p+"://platform.twitter.com/widgets.js";fjs.parentNode.insertBefore(js,fjs);}}(document, \'script\', \'twitter-wjs\');</script>\n\n  <link rel="stylesheet" type="text/css" href="/Styles/Events/index.css">\n\n  \n\n    <script type=\'text/javascript\'>\n    var googletag = googletag || {};\n    googletag.cmd = googletag.cmd || [];\n    (function() {\n    var gads = document.createElement(\'script\');\n    gads.async = true;\n    gads.type = \'text/javascript\';\n    var useSSL = \'https:\' == document.location.protocol;\n    gads.src = (useSSL ? \'https:\' : \'http:\') +\n    \'//www.googletagservices.com/tag/js/gpt.js\';\n    var node = document.getElementsByTagName(\'script\')[0];\n    node.parentNode.insertBefore(gads, node);\n    })();\n    function adslots() {\n      var retailSlots = $("body").find(".adslot").filter(":visible"), i = 0, slotR = new Array();\n      var houseSlots = $("body").find(".adslot").filter(":hidden"), j = 0, slotH = new Array();\n      if (retailSlots.length || houseSlots.length) {\n        googletag.cmd.push(function() {\n          $(retailSlots).each(function(){\n            var adUnit = $(this).attr(\'data-section\') + $(this).attr(\'data-ad-unit\');\n            var pageID = $(this).attr(\'data-pageid\');\n            \n            if (pageID) {\n              slotR[i] = googletag.defineSlot(\'/1017433/\'+adUnit, [$(this).width(), $(this).height()] ...

# %% [markdown]
# ### 2) "Soupify" the object
#
# ``` python
# soup = BeautifulSoup(res.content)
# ```

# %%
## code 
soup = BeautifulSoup(res.content)

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en-US" xmlns="https://www.w3.org/1999/xhtml" xmlns:fb="https://www.facebook.com/2008/fbml">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
# <link href="https://cloud.typography.com/7790492/668686/css/fonts.css" rel="stylesheet" type="text/css"/>
# <script src="https://use.fontawesome.com/1a933a8ada.js"></script>
# <link href="/Styles/responsive/ac-style.css?v=2.9" rel="stylesheet" type="text/css"/>
# <link href="/Styles/responsive/ac-menu.css" rel="stylesheet" type="text/css"/>
# <link href="/Styles/responsive/magnific.css" rel="stylesheet" type="text/css"/>
# <link href="/Styles/responsive/fluid.css?v=1.3" rel="stylesheet" type="text/css"/>
# <link href="/apple-icon-57x57.png?v=2" rel="apple-touch-icon" sizes="57x57"/>
# <link href="/apple-icon-60x60.png?v=2" rel="apple-touch-icon" sizes="60x60"/>
# <link href="/apple-icon-72x72.png?v=2" rel="apple-touch-icon" sizes="72x72"/>
# <link href="/apple-icon-76x76.png?v=2" rel="apple-touch-icon" sizes="76x76"/>
# <link href="/apple-icon-114x114.png?v=2" rel="apple-touch-icon" sizes="114x114"/>
# <link href="/apple-icon-120x120.png?v=2" rel="apple-touch-icon" sizes="120x120"/>
# <link href="/apple-icon-144x144.png?v=2" rel="apple-touch-icon" sizes="144x144"/>
# <link href="/apple-icon-152x152.png?v=2" rel="apple-touch-icon" sizes="152x152"/>
# <link href="/apple-icon-180x180.png?v=2" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/android-icon-192x192.png?v=2" rel="icon" sizes="192x192" type="image/png"/>
# <link href="/favicon-32x32.png?v=2" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/favicon-96x96.png?v=2" rel="icon" sizes="96x96" type="image/png"/>
# <link href="/favicon-16x16.png?v=2" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/favicon.ico?v=2" rel="shortcut icon"/>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.11.0/jquery.min.js"></script>
# <script src="/Scripts/responsive/ac-custom.js"></script>
# <script src="/Scripts/responsive/jquery.mmenu.min.js"></script>
# <script src="/Scripts/responsive/jquery.autoellipsis-1.0.10.min.js"></script>
# <script src="/Scripts/responsive/jquery.magnific.min.js"></script>
# <script>!function(d,s,id){var js,fjs=d.getElementsByTagName(s)[0],p=/^http:/.test(d.location)?'http':'https';if(!d.getElementById(id)){js=d.createElement(s);js.id=id;js.src=p+"://platform.twitter.com/widgets.js";fjs.parentNode.insertBefore(js,fjs);}}(document, 'script', 'twitter-wjs');</script>
# <link href="/Styles/Events/index.css" rel="stylesheet" type="text/css"/>
# <script type="text/javascript">
#     var googletag = googletag || {};
#     googletag.cmd = googletag.cmd || [];
#     (function() {
#     var gads = document.createElement('script');
#     gads.async = true;
#     gads.type = 'text/javascript';
#     var useSSL = 'https:' == document.location.protocol;
#     gads.src = (useSSL ? 'https:' : 'http:') +
#     '//www.googletagservices.com/tag/js/gpt.js';
#     var node = document.getElementsByTagName('script')[0];
#     node.parentNode.insertBefore(gads, node);
#     })();
#     function adslots() {
#       var retailSlots = $("body").find(".adslot").filter(":visible"), i = 0, slotR = new Array();
#       var houseSlots = $("body").find(".adslot").filter(":hidden"), j = 0, slotH = new Array();
#       if (retailSlots.length || houseSlots.length) {
#         googletag.cmd.push(function() {
#           $(retailSlots).each(function(){
#             var adUnit = $(this).attr('data-section') + $(this).attr('data-ad-unit');
#             var pageID = $(this).attr('data-pageid');
#
#             if (pageID) {
#               slotR[i] = googletag.defineSlot('/1017433/'+adUnit, [$(this).width(), $(this).height()], $(this).attr('id')).addService(googletag.pubads()).setTargeting('pageid', [pageID]);
#             } else {
#               slotR[i] = googletag.defineSlot('/1017433/'+adUnit, [$(this).width(), $(this).height()], $(this).attr('id')).addService(googletag.pubads());
#             }
#             i++
#           });
#           $(houseSlots).each(function(){
#             var adUnit = 'House' + $(this).attr('data-ad-unit');
#
#             slotH[j] = googletag.defineSlot('/1017433/'+adUnit, [$(this).width(), $(this).height()], $(this).attr('id')).addService(googletag.pubads());
#             j++
#           });
# //        googletag.pubads().collapseEmptyDivs(true);
#
#           googletag.pubads().enableSingleRequest();
#
#
#           googletag.enableServices();
#           $(retailSlots).each(function(){
#             googletag.display($(this).attr('id'));
#           });
#           $(houseSlots).each(function(){
#             googletag.display($(this).attr('id'));
#           });
#
#         });
#       } else {
# //        console.log('huh, both empty');
#       }
#     }
#     $(document).ready(function(){
#       setTimeout(adslots, 200)
#     });
#     </script>
# <title>Events - Music - Friday, January 17, 2020 - The Austin Chronicle</title>
# <meta content="" name="description"/>
# <meta content="qnrKtufqpmTjGUn37hMteGd7m_7o98t42RcbtZJAXRs" name="google-site-verification"/>
# <link href="https://plus.google.com/+austinchronicle" rel="publisher"/>
# <meta content="https://www.austinchronicle.com/Images/ChronEvents/ChronEvents_800x500.gif" property="og:image"/>
# <meta content="https://www.austinchronicle.com/Images/ChronEvents/ChronEvents_800x500.gif" name="twitter:image"/>
# <!-- Google Analytics -->
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#   ga('create', 'UA-397617-1', 'auto');
#   ga('send', 'pageview');
#   </script>
# <!-- End Google Analytics -->
# <!-- Facebook Pixel Code -->
# <script>
#   !function(f,b,e,v,n,t,s)
#   {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#   n.callMethod.apply(n,arguments):n.queue.push(arguments)};
#   if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
#   n.queue=[];t=b.createElement(e);t.async=!0;
#   t.src=v;s=b.getElementsByTagName(e)[0];
#   s.parentNode.insertBefore(t,s)}(window, document,'script',
#   'https://connect.facebook.net/en_US/fbevents.js');
#   fbq('init', '1796648420647973');
#   fbq('track', 'PageView');
# </script>
# <noscript><img height="1" src="https://www.facebook.com/tr?id=1796648420647973&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript>
# <!-- End Facebook Pixel Code -->
# </head>
# <body>
# <div id="total-containment">
# <!-- CalendarSkin -->
# <div class="adslot skin" data-ad-unit="Skin" data-section="Calendar" id="div-gpt-ad-1354205884549-0" style="width:1px;height:1px;"></div>
# <link href="/Styles/NewHeader.css?v=2.1" rel="stylesheet" type="text/css"/>
# <div id="head-section">
# <div id="top-leaderboard">
# <div class="adslot" data-ad-unit="Leaderboard" data-section="Calendar" id="div-gpt-ad-1354205884549-1" style="width:728px;height:90px;"></div>
# </div>
# <div id="nav-section">
# <div class="calendar-bar" id="top-bar">
# <div class="clear-fix" id="top-box">
# <div class="" id="bar-links-left">
# <a class="bar-link" href="#" id="bar-sections" onclick="ga('send', 'event', 'Chron Events Navigation', 'CATEGORIES button', 'Events - Music - Friday, January 17, 2020 - The Austin Chronicle');"><i aria-hidden="true" class="fa fa-bars"></i><i aria-hidden="true" class="fa fa-times-circle"></i><span> CATEGORIES</span></a>
# <a class="bar-link" href="" id="bar-search"><i aria-hidden="true" class="fa fa-search"></i> SEARCH</a>
# </div>
# <div id="bar-logo">
# <a href="/events/">
# <img alt="The Austin Chronicle Events" id="logo" src="/Images/ChronEvents/chron-events-80.png"/>
# </a>
# </div>
# <div class="" id="bar-links-right">
# <a class="bar-link" href="http://mediakit.austinchronicle.com/" id="bar-advertise" target="_blank"><i aria-hidden="true" class="fa fa-newspaper-o"></i> ADVERTISE</a>
# <a class="bar-link bar-social" href="https://squareup.com/store/the-austin-chronicle-2" id="bar-store" target="_blank" title="The Austin Chronicle Online Store"><i aria-hidden="true" class="fa fa-shopping-cart"></i></a>
# <a class="bar-link bar-social" href="https://www.facebook.com/ChronEvents/" id="bar-facebook" target="_blank" title="Chron Events on Facebook"><i class="fa fa-facebook fa-lg"></i></a>
# <a class="bar-link bar-social" href="https://twitter.com/ChronEvents" id="bar-twitter" target="_blank" title="Chron Events on Twitter"><i class="fa fa-twitter fa-lg"></i></a>
# <a class="bar-link bar-social" href="https://www.instagram.com/chronevents/" id="bar-instagram" target="_blank" title="Chron Events on Instagram"><i class="fa fa-instagram fa-lg"></i></a>
# <a class="bar-link" href="" id="bar-search-m"><i aria-hidden="true" class="fa fa-search"></i><span> SEARCH</span></a>
# </div>
# </div>
# </div>
# <div id="top-links">
# <a class="top-link" href="/events/2020-01-17/" id="all-events-top-link" onclick="ga('send', 'event', 'Top Navigation', 'All Events');">      All Events
#     </a>
# <a class="top-link" href="/events/music/2020-01-17/" id="music-top-link" onclick="ga('send', 'event', 'Top Navigation', 'Music');">      Music
#     </a>
# <a class="top-link" href="/events/film/" id="movies-top-link" onclick="ga('send', 'event', 'Top Navigation', 'Movies');">      Movies
#     </a>
# <a class="top-link" href="/events/food/2020-01-17/" id="food-top-link" onclick="ga('send', 'event', 'Top Navigation', 'Food');">      Food
#     </a>
# <a class="top-link" href="/events/community/2020-01-17/" id="community-top-link" onclick="ga('send', 'event', 'Top Navigation', 'Community');">      Community
#     </a>
# <a class="top-link" href="/events/arts/2020-01-17/" id="arts-top-link" onclick="ga('send', 'event', 'Top Navigation', 'Arts');">      Arts
#     </a>
# <a class="top-link" href="/events/qmmunity/2020-01-17/" id="queer-top-link" onclick="ga('send', 'event', 'Top Navigation', 'Queer');">      Queer
#     </a>
# <a class="top-link" href="/daily/events/" id="blog-top-link" onclick="ga('send', 'event', 'Top Navigation', 'Blog');">      Blog
#     </a>
# <a class="top-link" href="/events-and-promotions/contests/" id="contests-top-link" onclick="ga('send', 'event', 'Top Navigation', 'Contests');">      Contests
#     </a>
# <a class="top-link" href="/" id="chronicle-top-link" onclick="ga('send', 'event', 'Top Navigation', 'Chronicle');">      Chronicle
#     </a>
# <a class="top-link" href="/support/" id="support-us-top-link" onclick="ga('send', 'event', 'Top Navigation', 'Support Us');">      Support Us
#     </a>
# </div>
# <div id="search-box">
# <form>
# <input id="search-input" type="text" value=""/>
# <input class="search-button" id="search-submit" type="submit" value="SEARCH"/>
# <div class="search-button" id="search-cancel">CANCEL</div>
# </form>
# </div>
# </div>
# <div class="menu-mobile menu-events" id="menu-box"><div id="menu-liner">
# <a class="menu-button no-sub" href="/events/" id="home-button">Events Home</a>
# <div class="menu-spacer" style="margin-bottom:4px;"></div>
# <a class="menu-button no-sub" href="/"><i>The Austin Chronicle</i></a>
# <div class="menu-spacer" style="margin-bottom:4px;"></div>
# <a class="menu-button special-button no-sub" href="/vote-austin-music-awards/?utm_source=site&amp;utm_medium=sitemap&amp;utm_campaign=musicpoll" onclick="ga('send', 'event', 'Top Navigation', 'Music Poll Ballot', 'Events');">Music Poll Ballot</a>
# <a class="menu-button special-button no-sub" href="/av/" onclick="ga('send', 'event', 'Top Navigation', 'Audio/Video', 'Events');">Audio/Video</a>
# <a class="menu-button no-sub" href="/events/austin-events/" onclick="ga('send', 'event', 'Chron Events Navigation', 'Annual Austin Events', 'Annual Austin Events - The Austin Chronicle');">Annual Austin Events</a>
# <div class="menu-spacer" style="margin-bottom:4px;"></div>
# <a class="menu-button no-sub" href="/events/music/2020-01-17/" id="music events-link" onclick="ga('send', 'event', 'Chron Events Navigation', 'Live Music', 'Events');">Live Music</a>
# <div class="sub-cats" id="music events-menu">
# <a class="menu-button" href="/events/music/roadshows/" onclick="ga('send', 'event', 'Chron Events Navigation', 'Roadshows', 'Events');">Roadshows</a>
# <a class="menu-button" href="/events/music/venues/" onclick="ga('send', 'event', 'Chron Events Navigation', 'Live Music Venues', 'Events');">Live Music Venues</a>
# </div>
# <a class="menu-button no-sub" href="/events/film/" id="movies-link" onclick="ga('send', 'event', 'Chron Events Navigation', 'Movies: New This Week', 'Events');">Movies: New This Week</a>
# <div class="sub-cats" id="movies-menu">
# <a class="menu-button" href="/events/film/showtimes-by-theatre/" onclick="ga('send', 'event', 'Chron Events Navigation', 'Showtimes by Theatre', 'Events');">Showtimes by Theatre</a>
# <a class="menu-button" href="/events/film/showtimes-by-movie/" onclick="ga('send', 'event', 'Chron Events Navigation', 'Showtimes by Movie', 'Events');">Showtimes by Movie</a>
# <a class="menu-button" href="/events/film/special-screenings/" onclick="ga('send', 'event', 'Chron Events Navigation', 'Special Screenings', 'Events');">Special Screenings</a>
# <a class="menu-button" href="/gyrobase/calendar/film/browse" onclick="ga('send', 'event', 'Chron Events Navigation', 'Movie Review Archive', 'Events');">Movie Review Archive</a>
# </div>
# <a class="menu-button no-sub" href="/events/food/2020-01-17/" id="food &amp; drink-link" onclick="ga('send', 'event', 'Chron Events Navigation', 'Food &amp; Drink', 'Events');">Food &amp; Drink</a>
# <div class="sub-cats" id="food &amp; drink-menu">
# </div>
# <a class="menu-button no-sub" href="/events/community/2020-01-17/" id="community events-link" onclick="ga('send', 'event', 'Chron Events Navigation', 'Community Events', 'Events');">Community Events</a>
# <div class="sub-cats" id="community events-menu">
# <a class="menu-button" href="/events/community/events/2020-01-17/" onclick="ga('send', 'event', 'Chron Events Navigation', 'General Events', 'Events');">General Events</a>
# <a class="menu-button" href="/events/community/kids/2020-01-17/" onclick="ga('send', 'event', 'Chron Events Navigation', 'Kids', 'Events');">Kids</a>
# <a class="menu-button" href="/events/community/out-of-town/2020-01-17/" onclick="ga('send', 'event', 'Chron Events Navigation', 'Out of Town', 'Events');">Out of Town</a>
# <a class="menu-button" href="/events/community/sports/2020-01-17/" onclick="ga('send', 'event', 'Chron Events Navigation', 'Sports &amp; Fitness', 'Events');">Sports &amp; Fitness</a>
# <a class="menu-button" href="/events/community/civic-events/2020-01-17/" onclick="ga('send', 'event', 'Chron Events Navigation', 'Civic Events', 'Events');">Civic Events</a>
# </div>
# <a class="menu-button no-sub" href="/events/arts/2020-01-17/" id="arts events-link" onclick="ga('send', 'event', 'Chron Events Navigation', 'Arts Events', 'Events');">Arts Events</a>
# <div class="sub-cats" id="arts events-menu">
# <a class="menu-button" href="/events/arts/visual-arts/2020-01-17/" onclick="ga('send', 'event', 'Chron Events Navigation', 'Visual Arts', 'Events');">Visual Arts</a>
# <a class="menu-button" href="/events/arts/theatre/2020-01-17/" onclick="ga('send', 'event', 'Chron Events Navigation', 'Theatre', 'Events');">Theatre</a>
# <a class="menu-button" href="/events/arts/comedy/2020-01-17/" onclick="ga('send', 'event', 'Chron Events Navigation', 'Comedy', 'Events');">Comedy</a>
# <a class="menu-button" href="/events/arts/books/2020-01-17/" onclick="ga('send', 'event', 'Chron Events Navigation', 'Books', 'Events');">Books</a>
# <a class="menu-button" href="/events/arts/dance/2020-01-17/" onclick="ga('send', 'event', 'Chron Events Navigation', 'Dance', 'Events');">Dance</a>
# <a class="menu-button" href="/events/arts/classical-music/2020-01-17/" onclick="ga('send', 'event', 'Chron Events Navigation', 'Classical Music', 'Events');">Classical Music</a>
# </div>
# <a class="menu-button no-sub" href="/events/qmmunity/2020-01-17/" id="qmmunity-link" onclick="ga('send', 'event', 'Chron Events Navigation', 'Qmmunity Events', 'Events');">Qmmunity Events</a>
# <div class="sub-cats" id="qmmunity-menu">
# <a class="menu-button" href="/events/qmmunity/nightlife-and-parties/2020-01-17/" onclick="ga('send', 'event', 'Chron Events Navigation', 'Nightlife &amp; Parties', 'Events');">Nightlife &amp; Parties</a>
# <a class="menu-button" href="/events/qmmunity/arts-and-culture/2020-01-17/" onclick="ga('send', 'event', 'Chron Events Navigation', 'Arts &amp; Culture', 'Events');">Arts &amp; Culture</a>
# <a class="menu-button" href="/events/qmmunity/community/2020-01-17/" onclick="ga('send', 'event', 'Chron Events Navigation', 'Community', 'Events');">Community</a>
# </div>
# <a class="menu-button no-sub" href="/daily/events/" id="chron events blog-link" onclick="ga('send', 'event', 'Chron Events Navigation', 'Chron Events Blog', 'Events');">Chron Events Blog</a>
# <div class="sub-cats" id="chron events blog-menu">
# </div>
# <a class="menu-button no-sub" href="/events-and-promotions/contests/" id="contests-link" onclick="ga('send', 'event', 'Chron Events Navigation', 'Contests', 'Events');">Contests</a>
# <div class="sub-cats" id="contests-menu">
# </div>
# <a class="menu-button no-sub" href="/event-submission/" id="submit an event-link" onclick="ga('send', 'event', 'Chron Events Navigation', 'Submit an Event', 'Events');">Submit an Event</a>
# <div class="sub-cats last-menu" id="submit an event-menu">
# </div>
# <div class="menu-spacer"></div>
# <a class="menu-button no-sub" href="http://mediakit.austinchronicle.com" target="_blank">Advertise With Us</a>
# <a class="menu-button no-sub" href="/support/">Support the Chronicle</a>
# </div></div>
# </div>
# <div id="menu-skin" onclick="void(0)"></div>
# <div class="top-ad"><div class="adslot" data-ad-unit="Littleboard" data-section="Calendar" id="div-gpt-ad-1354205884549-2" style="width:320px;height:50px;"></div></div>
# <!-- DesktopPushdown -->
# <div class="adslot desktop-pushdown" data-ad-unit="DesktopPushdown" data-section="" id="div-gpt-ad-1354205884549-9" style="width:970px;height:30px;"></div>
# <div class="clear-fix" id="content-area">
# <script src="/Scripts/NewHeader.js?v=1.7"></script>
# <!-- Included Templates: /Templates/Events/index.html /Helpers/Events/Common.html, /Helpers/Events/index.html -->
# <div id="cal-left">
# <h1><a href="/events/">Home</a> <i aria-hidden="true" class="fa fa-caret-right"></i> <a href="/events/2020-01-17/">Events</a> <i aria-hidden="true" class="fa fa-caret-right"></i> <span class="nobr">Live Music</span></h1>
# <div id="featured-links-outer">
# <div id="featured-links-inner">
# <span class="exhale" id="featured-links"><a href="/events/music/roadshows/" onclick="ga('send', 'event', 'Top Navigation', 'Roadshows', 'Events');"><span class="featured-link">Roadshows</span></a> <a href="/events/music/venues/" onclick="ga('send', 'event', 'Top Navigation', 'Live Music Venues', 'Events');"><span class="featured-link">Live Music Venues</span></a> <span class="featured-link">also: <a href="/music/">Music News</a></span></span>
# </div>
# </div>
# <div style="float:left;clear:both;"><a name="content-top"></a></div>
# <div id="nav-elements">
# <a href="#">
# <div id="menu-sections">
# <i aria-hidden="true" class="fa fa-bars"></i> CATEGORIES
#       </div>
# </a>
# <a href="#">
# <div id="topSearchButton">
# <i aria-hidden="true" class="fa fa-search"></i>
# </div>
# </a>
# <div class="" id="date-controls">
# <a class="date-shift-link" href="/events/music/2020-01-16/" title="previous day">
# <div class="dateShift date-back">
# <span class="point-left"><i aria-hidden="true" class="fa fa-arrow-left"></i></span>
# </div>
# </a>
# <a href="#" id="calButton2" title="pick a date">
# <div id="topDateNav">
#           FRI. JAN. 17 <i aria-hidden="true" class="fa fa-calendar-o"></i>
# </div>
# </a>
# <a class="date-shift-link" href="/events/music/2020-01-18/" title="next day">
# <div class="dateShift date-next">
# <span class="point-right"><i aria-hidden="true" class="fa fa-arrow-right"></i></span>
# </div>
# </a>
# </div>
# </div>
# <div id="container-container">
# <div id="nav-container">
# <div class="nav-spacer top-spacer"></div>
# <a class="nav-link" href="/calendar/2020-01-17/">
# <div class="nav-button solo-button">
#     All Events
#   </div>
# </a>
# <div class="nav-spacer"></div>
# <a class="nav-link" href="/calendar/music/2020-01-17/">
# <div class="nav-button first-button">
#         Music
#       </div>
# </a>
# <a class="nav-link" href="/calendar/music/2020-01-17/">
# <div class="nav-button sub-button">
#         Club Listings
#       </div>
# </a>
# <a class="nav-link" href="/calendar/music/roadshows/">
# <div class="nav-button sub-button">
#         Upcoming Roadshows
#       </div>
# </a>
# <a class="nav-link" href="/calendar/music/venues/">
# <div class="nav-button sub-button last-button">
#         Live Music Venues
#       </div>
# </a>
# <div class="nav-spacer"></div>
# <a class="nav-link" href="/calendar/Valentine's Events/">
# <div class="nav-button special-button solo-button">
#       /events/valentines-events/
#     </div>
# </a>
# <div class="nav-spacer"></div>
# <a class="nav-link" href="/calendar/Annual Austin Events/">
# <div class="nav-button special-button solo-button">
#       /events/austin-events/
#     </div>
# </a>
# <div class="nav-spacer"></div>
# <a class="nav-link" href="/calendar/film/">
# <div class="nav-button first-button">
#         Film
#       </div>
# </a>
# <a class="nav-link" href="/calendar/film/">
# <div class="nav-button sub-button">
#         New This Week
#       </div>
# </a>
# <a class="nav-link" href="/calendar/film/showtimes-by-theatre/">
# <div class="nav-button sub-button">
#         Showtimes by Theatre
#       </div>
# </a>
# <a class="nav-link" href="/calendar/film/showtimes-by-movie/">
# <div class="nav-button sub-button">
#         Showtimes by Movie
#       </div>
# </a>
# <a class="nav-link" href="/calendar/film/special-screenings/">
# <div class="nav-button sub-button">
#         Special Screenings
#       </div>
# </a>
# <a class="nav-link" href="/gyrobase/calendar/film/browse">
# <div class="nav-button sub-button">
#         Film Review Archive
#       </div>
# </a>
# <a class="nav-link" href="/calendar/offscreen/2020-01-17/">
# <div class="nav-button sub-button last-button">
#         Offscreen Listings
#       </div>
# </a>
# <div class="nav-spacer"></div>
# <a class="nav-link" href="/calendar/food/2020-01-17/">
# <div class="nav-button first-button">
#         Food
#       </div>
# </a>
# <a class="nav-link" href="/calendar/food/2020-01-17/">
# <div class="nav-button sub-button">
#         All Food Events
#       </div>
# </a>
# <a class="nav-link" href="/calendar/food-events/2020-01-17/">
# <div class="nav-button sub-button last-button">
#         Food Events
#       </div>
# </a>
# <div class="nav-spacer"></div>
# <a class="nav-link" href="/calendar/arts/2020-01-17/">
# <div class="nav-button first-button">
#         Arts
#       </div>
# </a>
# <a class="nav-link" href="/calendar/arts/2020-01-17/">
# <div class="nav-button sub-button">
#         All Arts Events
#       </div>
# </a>
# <a class="nav-link" href="/calendar/theatre/2020-01-17/">
# <div class="nav-button sub-button">
#         Theatre
#       </div>
# </a>
# <a class="nav-link" href="/calendar/comedy/2020-01-17/">
# <div class="nav-button sub-button">
#         Comedy
#       </div>
# </a>
# <a class="nav-link" href="/calendar/dance/2020-01-17/">
# <div class="nav-button sub-button">
#         Dance
#       </div>
# </a>
# <a class="nav-link" href="/calendar/classical-music/2020-01-17/">
# <div class="nav-button sub-button">
#         Classical Music
#       </div>
# </a>
# <a class="nav-link" href="/calendar/visual-arts/2020-01-17/">
# <div class="nav-button sub-button">
#         Visual Arts
#       </div>
# </a>
# <a class="nav-link" href="/calendar/books/2020-01-17/">
# <div class="nav-button sub-button">
#         Books
#       </div>
# </a>
# <a class="nav-link" href="/calendar/offscreen/2020-01-17/">
# <div class="nav-button sub-button last-button">
#         Offscreen
#       </div>
# </a>
# <div class="nav-spacer"></div>
# <a class="nav-link" href="/calendar/community/2020-01-17/">
# <div class="nav-button first-button">
#         Community
#       </div>
# </a>
# <a class="nav-link" href="/calendar/community/2020-01-17/">
# <div class="nav-button sub-button">
#         All Community Events
#       </div>
# </a>
# <a class="nav-link" href="/calendar/events/2020-01-17/">
# <div class="nav-button sub-button">
#         General
#       </div>
# </a>
# <a class="nav-link" href="/calendar/kids/2020-01-17/">
# <div class="nav-button sub-button">
#         Kids
#       </div>
# </a>
# <a class="nav-link" href="/calendar/out-of-town/2020-01-17/">
# <div class="nav-button sub-button">
#         Out of Town
#       </div>
# </a>
# <a class="nav-link" href="/calendar/sports/2020-01-17/">
# <div class="nav-button sub-button">
#         Sports
#       </div>
# </a>
# <a class="nav-link" href="/calendar/the-gay-place/2020-01-17/">
# <div class="nav-button sub-button">
#         The Gay Place
#       </div>
# </a>
# <a class="nav-link" href="/calendar/civic-events/2020-01-17/">
# <div class="nav-button sub-button">
#         Civic Events
#       </div>
# </a>
# <a class="nav-link" href="/calendar/yoga/2020-01-17/">
# <div class="nav-button sub-button last-button">
#         Yoga
#       </div>
# </a>
# <div class="nav-spacer"></div>
# <a class="nav-link" href="/event-submission/">
# <div class="nav-button solo-button">
#     Submit an Event
#   </div>
# </a>
# <div class="nav-spacer"></div>
# <a class="nav-link" href="#">
# <div class="nav-button sub-button close-button" id="close-nav">
#     CLOSE MENU <i aria-hidden="true" class="fa fa-arrow-up"></i>
# </div>
# </a>
# </div>
# </div>
# <div id="popCalendar2" style="display:none;margin:0 0 10px;padding:0;float:left;width:100%;">
# <div id="cal-container">
# <div class="datePicker" id="2020-01-17-datePicker">
# <div class="dateBox" id="dateBox-pick-month" style="display:none;">
# <a class="nav-clicker" href="#" id="jumpTo-2020-01-01">
# <div class="month-name no-margin top-both">
#               January 2020
#             </div>
# </a>
# <a class="nav-clicker" href="#" id="jumpTo-2020-02-01">
# <div class="month-name no-margin">
#               February 2020
#             </div>
# </a>
# <a class="nav-clicker" href="#" id="jumpTo-2020-03-01">
# <div class="month-name no-margin">
#               March 2020
#             </div>
# </a>
# <a class="nav-clicker" href="#" id="jumpTo-2020-04-01">
# <div class="month-name no-margin">
#               April 2020
#             </div>
# </a>
# <a class="nav-clicker" href="#" id="jumpTo-2020-05-01">
# <div class="month-name no-margin">
#               May 2020
#             </div>
# </a>
# <a class="nav-clicker" href="#" id="jumpTo-2020-06-01">
# <div class="month-name no-margin bottom-both">
#               June 2020
#             </div>
# </a>
# <div class="venue"><a href="/locations/buzz-mill-coffee-1442057/" title="more about Buzz Mill Riverside">Buzz Mill Riverside</a></div>
# </div>
# </li>
# <li class="list-item">
# <h4 class="event-cat-tag active">Music</h4>
# <div class="event-spacer"></div>
# <div class="clear"></div>
# <div class="event-text">
# <h2><a href="/events/music/cass-brostad-closed-mic-2642211/">Cass Brostad closed mic</a></h2>
# <div class="date-time">Third Friday of every month, 8pm</div>
# <div class="venue"><a href="/locations/buzz-mill-shady-2595577/" title="more about Buzz Mill Shady">Buzz Mill Shady</a></div>
# </div>
# </li>
# <li class="list-item multi-item">
# <h4 class="event-cat-tag active">Music</h4>
# <div class="event-spacer"></div>
# <div class="clear"></div>
# <div class="event-text">
# <h2><a href="/events/music/marshall-hood-2663291/">Marshall Hood</a></h2>
# <div class="date-time"><span class="event-date">Fri., Jan. 17</span>, 6:30pm</div>
# </div>
# <div class="event-text">
# <h2><a href="/events/music/mike-flanigin-trio-w-jimmie-vaughan-2634297/">Mike Flanigin Trio w/ Jimmie Vaughan</a></h2>
# <div class="date-time"><span class="event-date">Fri., Jan. 17</span>, 10:30pm</div>
# <div class="venue"><a href="/locations/c-boys-heart-and-soul-1503759/" title="more about C-Boy's Heart &amp; Soul">C-Boy's Heart &amp; Soul</a></div>
# </div>
# </li>
# <li class="list-item">
# <h4 class="event-cat-tag active">Music</h4>
# <div class="event-spacer"></div>
# <div class="clear"></div>
# <div class="event-text">
# <h2><a href="/events/music/tara-williamson-2641733/">Tara Williamson</a></h2>
# <div class="date-time">Fridays, 6:30pm</div>
# <div class="venue"><a href="/locations/the-capital-grille-1536620/" title="more about The Capital Grille">The Capital Grille</a></div>
# </div>
# </li>
# <li class="list-item multi-item">
# <h4 class="event-cat-tag active">Music</h4>
# <div class="event-spacer"></div>
# <div class="clear"></div>
# <div class="event-text">
# <h2><a href="/events/music/variety-jones-2639432/">Variety Jones</a></h2>
# <div class="date-time"><span class="event-date">Fri., Jan. 17</span>, 5pm</div>
# </div>
# <div class="event-text">
# <h2><a href="/events/music/birds-on-a-wire-2639431/">Birds on a Wire</a></h2>
# <div class="date-time"><span class="event-date">Fri., Jan. 17</span>, 7pm</div>
# </div>
# <div class="event-text">
# <h2><a href="/events/music/the-morandies-futon-blonde-2639430/">The Morandies, Futon Blonde, Julian Berdegue</a></h2>
# <div class="date-time"><span class="event-date">Fri., Jan. 17</span>, 9pm</div>
# <div class="venue"><a href="/locations/carousel-lounge-44461/" title="more about Carousel Lounge">Carousel Lounge</a></div>
# </div>
# </li>
# <li class="list-item">
# <h4 class="event-cat-tag active">Music</h4>
# <div class="event-spacer"></div>
# <div class="clear"></div>
# <div class="event-text">
# <h2><a href="/events/music/reinier-zonneveld-brennen-grey-2629460/">Reinier Zonneveld, Brennen Grey</a></h2>
# <div class="date-time"><span class="event-date">Fri., Jan. 17</span>, 9pm</div>
# <div class="venue"><a href="/locations/cedar-street-44488/" title="more about Cedar Street Courtyard">Cedar Street Courtyard</a></div>
# </div>
# </li>
# <li class="list-item">
# <h4 class="event-cat-tag active">Music</h4>
# <div class="event-spacer"></div>
# <div class="clear"></div>
# <div class="event-text">
# <h2><a href="/events/music/sydney-wright-kelsi-2642106/">Sydney Wright, Kelsi</a></h2>
# <div class="date-time"><span class="event-date">Fri., Jan. 17</span>, 7pm</div>
# <div class="venue"><a href="/locations/cenote-windsor-park-2282648/" title="more about Cenote Windsor Park">Cenote Windsor Park</a></div>
# </div>
# </li>
# <li class="list-item">
# <h4 class="event-cat-tag active">Music</h4>
# <div class="event-spacer"></div>
# <div class="clear"></div>
# <div class="event-text">
# <h2><a href="/events/music/cienfuegos-2655711/">Cienfuegos</a></h2>
# <div class="date-time"><span class="event-date">Fri., Jan. 17</span>, 6:30pm</div>
# <div class="venue"><a href="/locations/central-market-north-46795/" title="more about Central Market North">Central Market North</a></div>
# </div>
# </li>
# <div class="event-spacer"></div>
# <style>
# .page-navigation {
# float: left;
# width: 100%;
# margin-bottom: 20px;
# }
# .page-button {
# float: left;
# text-align: center;
# letter-spacing: 1px;
# font-family: 'Gotham A', 'Gotham B';
# font-weight: 700;
# font-style: normal;
# font-size: 18px;
# height: 20px;
# width: 96px;
# padding: 6px 0;
# color: #000000;
# background-color: #eeeeee;
# }
# .page-button.page-dead {
# color: #bbbbbb;
# }
# .page-button.page-index {
# width: calc(100% - 280px);
# }
# .page-button.page-first,
# .page-button.page-last {
# width: 36px;
# }
# .page-button.page-first {
# border-radius: 4px 0 0 4px;
# }
# .page-button.page-last {
# border-radius: 0 4px 4px 0;
# }
# .page-button.page-first,
# .page-button.page-back {
# margin-right: 4px;
# }
# .page-button.page-last,
# .page-button.page-next {
# margin-left: 4px;
# }
# a:hover .page-button {
# color: #ffffff;
# background-color: #000000;
# }
# @media(max-width: 660px) {
# .page-button {
# width: 36px;
# }
# .page-button.page-index {
# width: calc(100% - 160px);
# }
# .page-button span {
# display: none;
# }
# }
# </style>
# <div class="page-navigation">
# <div class="page-button page-first page-dead">
# <i aria-hidden="true" class="fa fa-fast-backward"></i>
# </div>
# <div class="page-button page-back page-dead">
# <i aria-hidden="true" class="fa fa-step-backward"></i> <span>BACK</span>
# </div>
# <div class="page-button page-index">1-30 of 131<span> EVENTS</span></div>
# <a href="/events/music/2020-01-17/page-2/" title="next">
# <div class="page-button page-next">
# <span>NEXT</span> <i aria-hidden="true" class="fa fa-step-forward"></i>
# </div>
# </a>
# <a href="/events/music/2020-01-17/page-5/" title="next">
# <div class="page-button page-last">
# <i aria-hidden="true" class="fa fa-fast-forward"></i>
# </div>
# </a>
# </div>
# </ul>
# <div id="chron-events-bottom-buttons">
# <a href="/event-submission/">
# <div class="top-nav-button" style="width:100%;">Submit an Event</div>
# </a>
# </div>
# </ul></section>
# </div>
# <div id="cal-right">
# <div id="ad-container">
# <div id="ad-spacer"></div>
# <div class="module ad-right"><div class="adslot" data-ad-unit="Rectangle" data-section="Calendar" id="div-gpt-ad-1354205884549-3" style="width:300px;height:250px;"></div></div>
# <div class="module ad-right"><div class="adslot" data-ad-unit="Rectangle2" data-section="Calendar" id="div-gpt-ad-1354205884549-5" style="width:300px;height:250px;"></div></div>
# </div>
# </div>
# <script>
# $(document).ready(function() {
#   $(document).scroll(function() {
#     var extraSpace = Math.floor($(window).height() - 580);
#     var fromBottom = Math.floor($(document).height() - $(document).scrollTop() - $(window).height() + extraSpace);
#     if ($(window).width() < 999) {
#       $('#ad-container').removeClass('fixed-container').css();
#     } else if (fromBottom < 192) {
#       var topOffset = Math.floor(60 - (192 - fromBottom));
#       $('#ad-container').addClass('fixed-container').css('top',topOffset+'px');
#     } else if ($(document).scrollTop() > 174) {
#       $('#ad-container').addClass('fixed-container').css('top','20px');
#     } else {
#       $('#ad-container').removeClass('fixed-container');
#     }
#   });
# });
# </script>
# <style>
# .description.full-text {
# line-height: 20px;
# }
# </style>
# </div>
# <!-- END PAGE BODY -->
# <!-- BEGIN FOOTER -->
# <!-- CalMusicBottomLB -->
# <div id="bottom-ad-desktop-wrapper">
# <div class="bottom-ad-desktop"><div class="adslot" data-ad-unit="BottomLB" data-section="Calendar" id="div-gpt-ad-1354205884549-10" style="width:728px;height:90px;"></div></div>
# </div>
# <div class="bottom-ad"><div class="adslot" data-ad-unit="BottomLittle" data-section="Calendar" id="div-gpt-ad-1354205884549-11" style="width:320px;height:50px;"></div></div>
# <div class="footer">
# <div class="footer-mobile">
#           Copyright © 1981-2020 Austin Chronicle Corp. All rights reserved.
#           <div class="footer-links"><a href="/contact/" onclick="ga('send', 'event', 'Bottom Links', 'Contact', 'Events');">CONTACT</a> • <a href="/privacy-policy/" onclick="ga('send', 'event', 'Bottom Links', 'Privacy Policy', 'Events');">PRIVACY POLICY</a> • <a href="http://mediakit.austinchronicle.com" onclick="ga('send', 'event', 'Bottom Links', 'Advertise With Us', 'Events');">ADVERTISE WITH US</a> • <a href="/jobs/" onclick="ga('send', 'event', 'Bottom Links', 'Internships &amp; Jobs', 'Events');">INTERNSHIPS &amp; JOBS</a> • <a href="/support/" onclick="ga('send', 'event', 'Bottom Links', 'Support Us', 'Events');">SUPPORT US</a> • <a href="https://squareup.com/store/the-austin-chronicle-2" onclick="ga('send', 'event', 'Bottom Links', 'Store', 'Events');">STORE</a> • <a href="/site-map/">SITE MAP</a></div>
# </div>
# </div>
# <!-- END FOOTER -->
# </div>
# <style type="text/css">
# #vote-bar {
# display: none;
# bottom: 0; left: 0;
# right: 0;
# position: fixed;
# z-index: 1001;
# }
# #vote-inner.hide-vote-bar,
# #final-footer.hide-vote-bar {
# display: none;
# }
# #vote-inner {
# text-align: center;
# background-color: gold;
# padding: 5px 34px 6px;
# font-size: 14px;
# line-height: 24px;
# font-family: 'Gotham A','Gotham B';
# font-weight: 900;
# color: #000000;
# letter-spacing: 0.5px;
# }
# #vote-inner::after {
# content: "";
# display: block;
# clear: both;
# }
# #vote-inner p {
# margin: 0;
# padding: 0;
# }
# #vote-button {
# display: inline-block;
# background-color: #ffffff;
# color: #000000;
# font-weight: 700;
# font-size: 13px;
# line-height: 18px;
# letter-spacing: 0;
# padding: 2px 10px 0px 15px;
# border-radius: 19px;
# text-transform: uppercase;
# }
# #vote-button:hover {
# text-decoration: none;
# color: #ffffff;
# background-color: #000000;
# box-shadow: 0 0 5px 2px rgba(255, 255, 255, 0.5);
# }
# #close-vote {
# position: absolute;
# top: 5px;
# right: 7px;
# font-size: 24px;
# line-height: 24px;
# color: #000000;
# }
# #close-vote-link {
# color: #000000;
# }
# #close-vote-link:hover {
# color: #ffffff;
# }
# #final-footer {
# clear: both;
# text-align: center;
# background-color: #2ba9d1;
# padding: 5px 34px 6px;
# font-size: 14px;
# line-height: 24px;
# font-family: 'Gotham A','Gotham B';
# font-weight: 900;
# color: #000000;
# letter-spacing: 0.5px;
# margin-top: 0;
# visibility: hidden;
# }
# #final-footer::after {
# content: "";
# display: block;
# clear: both;
# }
# #final-footer p {
# margin: 0;
# padding: 0;
# }
# body {
# margin-bottom: 0;
# }
# </style>
# <div id="vote-bar">
# <div id="vote-inner">
# <p>Time to vote! Music Poll 2019-20 balloting is underway   <a href="/vote-austin-music-awards/?utm_source=site&amp;utm_medium=popup&amp;utm_campaign=musicpoll" id="vote-button" target="_blank">VOTE NOW   <i aria-hidden="true" class="fa fa-arrow-right"></i></a></p>
# </div>
# <div id="close-vote">
# <a href="#" id="close-vote-link"><i aria-hidden="true" class="fa fa-window-close"></i></a>
# </div>
# </div>
# <div id="final-footer">
# <p>Time to Vote! Music Poll 2019-20 balloting is underway   <a href="/vote-austin-music-awards/?utm_source=site&amp;utm_medium=popup&amp;utm_campaign=musicpoll" id="vote-button" target="_blank">VOTE NOW   <i aria-hidden="true" class="fa fa-arrow-right"></i></a></p>
# </div>
# <script type="text/javascript">
# function setCookie(cname, cvalue, exdays) {
#   var d = new Date();
#   d.setTime(d.getTime() + (exdays * 24 * 60 * 60 * 1000));
#   var expires = "expires="+d.toUTCString();
#   document.cookie = cname + "=" + cvalue + ";" + expires + ";path=/";
# }
# function getCookie(cname) {
#   var name = cname + "=";
#   var ca = document.cookie.split(';');
#   for(var i = 0; i < ca.length; i++) {
#     var c = ca[i];
#     while (c.charAt(0) == ' ') {
#       c = c.substring(1);
#     }
#     if (c.indexOf(name) == 0) {
#       return c.substring(name.length, c.length);
#     }
#   }
#   return "";
# }
# $(document).ready(function() {
#   var hideVote = getCookie('hideVote');
#   if (hideVote != "") {
#     $('#vote-inner').addClass('hide-vote-bar');
#     $('#final-footer').addClass('hide-vote-bar');
#   }
#   $(window).scroll(function () {
#     if ($(window).scrollTop() > $('body').height() / 4) {
#       $('#vote-bar').slideDown(500);
#     } else {
#       $('#vote-bar').slideUp(500);
#     }
#   });
#   $('#close-vote-link').click(function(e) {
#     $('#vote-inner').addClass('hide-vote-bar');
#     $('#final-footer').addClass('hide-vote-bar');
#     setCookie("hideVote", "yes", 2);
#     e.preventDefault();
#   });
# });
# </script>
# <!-- Adblock Detection -->
# <script>
# var test = document.createElement('div');
# test.innerHTML = '&nbsp;';
# test.className = 'adsbox';
# document.body.appendChild(test);
# window.setTimeout(function() {
#   if (test.offsetHeight === 0) {
#
#     document.body.classList.add('adblock');
#     ga('send', 'event', 'Ad Setting', 'Adblock', 'Enabled');
#   }
#   test.remove();
# }, 400);
# </script>
# <!--end Adblock Detection -->
# </body>
# <script src="/Scripts/modernizr.custom.91323.js"></script>
# <script>
# function dotDot() {
#   $('.dotdotdot').ellipsis('a', { live: false });
#
#   $('.half-headline-section.dotdotdot').ellipsis('', { live: false });
#   $('.half-subhead-section.dotdotdot').ellipsis('', { live: false });
#   $('.article-description.dotdotdot').ellipsis('', { live: false });
#   $('.archive-description.dotdotdot').ellipsis('', { live: false });
#   $('.joint-description').ellipsis('', { live: false });
#   $('.module .dsq-widget-thread').ellipsis('', { live: false });
#   $('.intro-blog.contest').ellipsis('', { live: false });
#   $('.intro-blog.event').ellipsis('', { live: false });
#   $('.fifth-item-text.dotdotdot').ellipsis('', { live: false });
#   $('.dotdotdot a, a.archive-link').each(function() {
#     var titleText = $(this).attr('title');
#     if (/<\/i> /.test(titleText)) {
#       console.log('got one: '+titleText);
#       var htmlString = $(this).html();
#       var newString = htmlString.replace(/<\/i>/g,'</i> ');
#       $(this).html(newString);
#     }
#   });
#   $('.fifth-item-text.dotdotdot').each(function() {
#     var htmlString = $(this).html();
#     var newString = htmlString.replace(/<\/span>/g,'</span> ');
#     $(this).html(newString);
#   });
# }
# $(document).ready(function() {
#   dotDot();
# });
# $(window).resize(function() {
#   setTimeout(dotDot, 200)
# });
# $(document).ready(function() {
#   $('.lightbox').magnificPopup({
#     type: 'image',
#     closeOnContentClick: true,
#     mainClass: 'mfp-img-mobile',
#     image: {
#       verticalFit: false
#     }
#   });
#   $('.popup-gallery').magnificPopup({
#     delegate: 'a',
#     type: 'image',
#     tLoading: 'Loading image #%curr%...',
#     mainClass: 'mfp-img-mobile',
#     gallery: {
#       enabled: true,
#       navigateByImgClick: true,
#       preload: [0,1] // Will preload 0 - before current, and 1 after the current image
#     },
#     image: {
#       tError: '<a href="%url%">The image #%curr%</a> could not be loaded.',
#       titleSrc: function(item) {
#         return item.el.attr('title');
#       }
#     }
#   });
#   $('.wordbox').magnificPopup({
#     closeBtnInside: true
#   });
#   $('.simple-ajax-popup').magnificPopup({
#     type: 'ajax',
#     closeOnContentClick: false,
#     closeOnBgClick: false
#   });
#   $('#resend-email').magnificPopup({
#     type: 'ajax',
#     closeOnContentClick: false
#   });
#   $('.candidate-pop-link').magnificPopup({
#     type: 'inline',
#     midClick: true
#   });
#   $('.popup-youtube').magnificPopup({
#     disableOn: 700,
#     type: 'iframe',
#     mainClass: 'mfp-fade',
#     removalDelay: 160,
#     preloader: false,
#     fixedContentPos: false
#   });
# });
# </script>
# <!-- Start Quantcast tag -->
# <script type="text/javascript">
# _qoptions={
# qacct:"p-7apeS9pNVYMQo"
# };
# </script>
# <script src="https://edge.quantserve.com/quant.js"></script>
# <noscript>
# <img alt="Quantcast" border="0" height="1" src="https://pixel.quantserve.com/pixel/p-7apeS9pNVYMQo.gif" style="display: none;" width="1"/>
# </noscript>
# <!-- End Quantcast tag -->
# </html>

# %% [markdown]
# ### 3) Try and find the element that contains the venue

# %%
## code
for i in soup.find_all(name='div', attrs={'class': 'venue'}):
    print(i.text)
# Out:
# Stay Gold
# Threadgill's Old No. 1
# McCullough Theatre
# Barracuda
# Come & Take It Live
# The Electric Church
# One World Theatre
# The Austin Beer Garden Brewing Co.
# ACL Live at the Moody Theater
# Angel's Icehouse
# Antone's Nightclub
# Azul Tequila
# Banger's Sausage House & Beer Garden
# The Barn
# B.D. Riley's Irish Pub
# Black Sparrow Music Parlor
# Blindside Tattoo & Piercing
# Brentwood Social House
# Broken Spoke
# Buck's Backyard
# Buzz Mill Riverside
# Buzz Mill Shady
# C-Boy's Heart & Soul
# The Capital Grille
# Carousel Lounge
# Cedar Street Courtyard
# Cenote Windsor Park
# Central Market North

# %% [markdown]
# ### 4) What about the date and time?

# %%
## code 
for i in soup.find_all(name='div', attrs={'class':'date-time'})[:5]:
    print(i.text)
# Out:
# Sun., Jan 19., 9pm-12mid   get tickets
# Fri., Jan. 17, 8-10pm   get tickets
# Fri., Jan. 17, 7:30pm   get tickets
# Fri., Jan. 17, 10pm  get tickets
# Fri., Jan. 17, 8pm  get tickets

# %% [markdown]
# ### 5) A link and the artist?
#
# _Hint: Try setting a base url_

# %%
### code  
for i in soup.find_all('h2')[:5]:
    print(i.text)
    print(i.find('a').attrs['href'])
# Out:
# All Skate: Sundays at Stay Gold
# http://www.facebook.com/events/585614641982520/
# Songwriters Series: Nakia
# http://www.threadgills.com/events-old-no-1
# Andrew Cyrille Quartet
# /events/music/andrew-cyrille-quartet-2626679/
# Hikes (album release), the Kraken Quartet, Christelle Bofale
# /events/music/hikes-album-release-2632606/
# Lucifer, Savage Master, Overdose
# /events/music/lucifer-savage-master-overdose-2626825/

# %% [markdown]
# When making a dataframe/scraper, keep in mind what your rows and columns will represent from the webpage

# %% [markdown]
# ### 6) Refactoring - Find the element that contains all of the information we potentially need - then grab the individual items from that element

# %%
### code 
for i in soup.find_all(name='div', attrs={'class':'event-text'}):
    try:
        print(i.find(name='div', attrs={'class':'venue'}).text)
    except:
        print('no venue')
    try:
        print(i.find(name='span',attrs={'class':'event-date'}).text)
    except:
        print('no time')
    try:
        print(i.find('h2').text)
    except:
        print('no artist')
    try:
        print(i.find('h2').find('a').attrs['href'])
    except:
        print('no link')
# Out:
# Stay Gold
# no time
# All Skate: Sundays at Stay Gold
# http://www.facebook.com/events/585614641982520/
# Threadgill's Old No. 1
# no time
# Songwriters Series: Nakia
# http://www.threadgills.com/events-old-no-1
# McCullough Theatre
# Fri., Jan. 17
# Andrew Cyrille Quartet
# /events/music/andrew-cyrille-quartet-2626679/
# Barracuda
# Fri., Jan. 17
# Hikes (album release), the Kraken Quartet, Christelle Bofale
# /events/music/hikes-album-release-2632606/
# Come & Take It Live
# Fri., Jan. 17
# Lucifer, Savage Master, Overdose
# /events/music/lucifer-savage-master-overdose-2626825/
# The Electric Church
# Fri., Jan. 17
# Evergreen, ThunderStars (album release), Dottie
# /events/music/thunderstars-album-release-2654787/
# One World Theatre
# Fri., Jan. 17
# Dar Williams
# /events/music/dar-williams-2627543/
# The Austin Beer Garden Brewing Co.
# Fri., Jan. 17
# Snizz Boogie
# /events/music/snizz-boogie-2632574/
# ACL Live at the Moody Theater
# Fri., Jan. 17
# The Pink Floyd Laser Spectacular
# /events/music/the-pink-floyd-laser-spectacular-2624539/
# Angel's Icehouse
# Fri., Jan. 17
# Neel Cole
# /events/music/neel-cole-2629406/
# Antone's Nightclub
# Fri., Jan. 17
# Spafford, The Iceman Special
# /events/music/spafford-the-iceman-special-2629416/
# Azul Tequila
# no time
# Mariachi Relámpago
# /events/music/mariachi-relmpago-2467346/
# Banger's Sausage House & Beer Garden
# Fri., Jan. 17
# Sophia Johnson
# /events/music/sophia-johnson-2642046/
# The Barn
# Fri., Jan. 17
# Sentimental Family Band
# /events/music/sentimental-family-band-2636713/
# B.D. Riley's Irish Pub
# no time
# The Chancers, Daithi Arwine (6:00)
# /events/music/the-chancers-700-daithi-arwine-600-2468018/
# Black Sparrow Music Parlor
# Fri., Jan. 17
# Dongle, Stupid Drama, Space Cushion, Wild Tinderbox
# /events/music/dongle-2663245/
# Blindside Tattoo & Piercing
# Fri., Jan. 17
# Wail Noises, Jane Connelly
# /events/music/wail-noises-jane-connelly-2655310/
# Brentwood Social House
# Fri., Jan. 17
# Woot Talley
# /events/music/woot-talley-2642071/
# no venue
# Fri., Jan. 17
# Ben Rodgers
# /events/music/ben-rodgers-2642079/
# Broken Spoke
# Fri., Jan. 17
# Almost Johnny Cash
# /events/music/almost-johnny-cash-2653813/
# Buck's Backyard
# Fri., Jan. 17
# The Powell Brothers
# /events/music/the-powell-brothers-2642090/
# Buzz Mill Riverside
# Fri., Jan. 17
# Viktor Scot fundraiser w/ Clayton England, Cole McDonnell, Heavy Stars, Hope Irish, Jack Charles, Marine Kimono, Suna
# /events/music/viktor-scot-fundraiser-2642206/
# Buzz Mill Shady
# no time
# Cass Brostad closed mic
# /events/music/cass-brostad-closed-mic-2642211/
# no venue
# Fri., Jan. 17
# Marshall Hood
# /events/music/marshall-hood-2663291/
# C-Boy's Heart & Soul
# Fri., Jan. 17
# Mike Flanigin Trio w/ Jimmie Vaughan
# /events/music/mike-flanigin-trio-w-jimmie-vaughan-2634297/
# The Capital Grille
# no time
# Tara Williamson
# /events/music/tara-williamson-2641733/
# no venue
# Fri., Jan. 17
# Variety Jones
# /events/music/variety-jones-2639432/
# no venue
# Fri., Jan. 17
# Birds on a Wire
# /events/music/birds-on-a-wire-2639431/
# Carousel Lounge
# Fri., Jan. 17
# The Morandies, Futon Blonde, Julian Berdegue
# /events/music/the-morandies-futon-blonde-2639430/
# Cedar Street Courtyard
# Fri., Jan. 17
# Reinier Zonneveld, Brennen Grey
# /events/music/reinier-zonneveld-brennen-grey-2629460/
# Cenote Windsor Park
# Fri., Jan. 17
# Sydney Wright, Kelsi
# /events/music/sydney-wright-kelsi-2642106/
# Central Market North
# Fri., Jan. 17
# Cienfuegos
# /events/music/cienfuegos-2655711/

# %% [markdown]
# ### 7)   Put it in a data frame!

# %%
### code 

df = pd.DataFrame(columns=['artist', 'venue', 'time', 'link'])

### code 
for i in soup.find_all(name='div', attrs={'class':'event-text'}):
    try:
        print(i.find(name='div', attrs={'class':'venue'}).text)
    except:
        print('no venue')
    try:
        print(i.find(name='span',attrs={'class':'event-date'}).text)
    except:
        print('no time')
    try:
        print(i.find('h2').text)
    except:
        print('no artist')
    try:
        print(i.find('h2').find('a').attrs['href'])
    except:
        print('no link')
# Variety Jones
# /events/music/variety-jones-2639432/
# no venue
# Fri., Jan. 17
# Birds on a Wire
# /events/music/birds-on-a-wire-2639431/
# Carousel Lounge
# Fri., Jan. 17
# The Morandies, Futon Blonde, Julian Berdegue
# /events/music/the-morandies-futon-blonde-2639430/
# Cedar Street Courtyard
# Fri., Jan. 17
# Reinier Zonneveld, Brennen Grey
# /events/music/reinier-zonneveld-brennen-grey-2629460/
# Cenote Windsor Park
# Fri., Jan. 17
# Sydney Wright, Kelsi
# /events/music/sydney-wright-kelsi-2642106/
# Central Market North
# Fri., Jan. 17
# Cienfuegos
# /events/music/cienfuegos-2655711/

# %%
### code 
df = pd.DataFrame(columns=['artist', 'venue', 'time', 'link'])
for i in soup.find_all(name='div', attrs={'class':'event-text'}):
    try:
        venue = i.find(name='div', attrs={'class':'venue'}).text
    except:
        venue = 'no venue'
    try:
        time = i.find(name='span',attrs={'class':'event-date'}).text
    except:
        time = 'no time'
    try:
        artist = i.find('h2').text
    except:
        artist = 'no artist'
    try:
        link = i.find('h2').find('a').attrs['href']
    except:
        link = 'no link'
    df.loc[len(df)] = [artist, venue, time, link]

# %%
df
# Out:
#                                                artist  \
# 0                     All Skate: Sundays at Stay Gold
# 1                           Songwriters Series: Nakia
# 2                              Andrew Cyrille Quartet
# 3   Hikes (album release), the Kraken Quartet, Chr...
# 4                    Lucifer, Savage Master, Overdose
# 5     Evergreen, ThunderStars (album release), Dottie
# 6                                        Dar Williams
# 7                                        Snizz Boogie
# 8                    The Pink Floyd Laser Spectacular
# 9                                           Neel Cole
# 10                       Spafford, The Iceman Special
# 11                                 Mariachi Relámpago
# 12                                     Sophia Johnson
# 13                            Sentimental Family Band
# 14                 The Chancers, Daithi Arwine (6:00)
# 15  Dongle, Stupid Drama, Space Cushion, Wild Tind...
# 16                         Wail Noises, Jane Connelly
# 17                                        Woot Talley
# 18                                        Ben Rodgers
# 19                                 Almost Johnny Cash
# 20                                The Powell Brothers
# 21  Viktor Scot fundraiser w/ Clayton England, Col...
# 22                            Cass Brostad closed mic
# 23                                      Marshall Hood
# 24               Mike Flanigin Trio w/ Jimmie Vaughan
# 25                                    Tara Williamson
# 26                                      Variety Jones
# 27                                    Birds on a Wire
# 28       The Morandies, Futon Blonde, Julian Berdegue
# 29                    Reinier Zonneveld, Brennen Grey
# 30                               Sydney Wright, Kelsi
# 31                                         Cienfuegos
#
#                                    venue           time  \
# 0                              Stay Gold        no time
# 1                 Threadgill's Old No. 1        no time
# 2                     McCullough Theatre  Fri., Jan. 17
# 3                              Barracuda  Fri., Jan. 17
# 4                    Come & Take It Live  Fri., Jan. 17
# 5                    The Electric Church  Fri., Jan. 17
# 6                      One World Theatre  Fri., Jan. 17
# 7     The Austin Beer Garden Brewing Co.  Fri., Jan. 17
# 8          ACL Live at the Moody Theater  Fri., Jan. 17
# 9                       Angel's Icehouse  Fri., Jan. 17
# 10                    Antone's Nightclub  Fri., Jan. 17
# 11                          Azul Tequila        no time
# 12  Banger's Sausage House & Beer Garden  Fri., Jan. 17
# 13                              The Barn  Fri., Jan. 17
# 14                B.D. Riley's Irish Pub        no time
# 15            Black Sparrow Music Parlor  Fri., Jan. 17
# 16           Blindside Tattoo & Piercing  Fri., Jan. 17
# 17                Brentwood Social House  Fri., Jan. 17
# 18                              no venue  Fri., Jan. 17
# 19                          Broken Spoke  Fri., Jan. 17
# 20                       Buck's Backyard  Fri., Jan. 17
# 21                   Buzz Mill Riverside  Fri., Jan. 17
# 22                       Buzz Mill Shady        no time
# 23                              no venue  Fri., Jan. 17
# 24                  C-Boy's Heart & Soul  Fri., Jan. 17
# 25                    The Capital Grille        no time
# 26                              no venue  Fri., Jan. 17
# 27                              no venue  Fri., Jan. 17
# 28                       Carousel Lounge  Fri., Jan. 17
# 29                Cedar Street Courtyard  Fri., Jan. 17
# 30                   Cenote Windsor Park  Fri., Jan. 17
# 31                  Central Market North  Fri., Jan. 17
#
#                                                  link
# 0     http://www.facebook.com/events/585614641982520/
# 1          http://www.threadgills.com/events-old-no-1
# 2       /events/music/andrew-cyrille-quartet-2626679/
# 3          /events/music/hikes-album-release-2632606/
# 4   /events/music/lucifer-savage-master-overdose-2...
# 5   /events/music/thunderstars-album-release-2654787/
# 6                 /events/music/dar-williams-2627543/
# 7                 /events/music/snizz-boogie-2632574/
# 8   /events/music/the-pink-floyd-laser-spectacular...
# 9                    /events/music/neel-cole-2629406/
# 10  /events/music/spafford-the-iceman-special-2629...
# 11           /events/music/mariachi-relmpago-2467346/
# 12              /events/music/sophia-johnson-2642046/
# 13     /events/music/sentimental-family-band-2636713/
# 14  /events/music/the-chancers-700-daithi-arwine-6...
# 15                      /events/music/dongle-2663245/
# 16   /events/music/wail-noises-jane-connelly-2655310/
# 17                 /events/music/woot-talley-2642071/
# 18                 /events/music/ben-rodgers-2642079/
# 19          /events/music/almost-johnny-cash-2653813/
# 20         /events/music/the-powell-brothers-2642090/
# 21      /events/music/viktor-scot-fundraiser-2642206/
# 22     /events/music/cass-brostad-closed-mic-2642211/
# 23               /events/music/marshall-hood-2663291/
# 24  /events/music/mike-flanigin-trio-w-jimmie-vaug...
# 25             /events/music/tara-williamson-2641733/
# 26               /events/music/variety-jones-2639432/
# 27             /events/music/birds-on-a-wire-2639431/
# 28  /events/music/the-morandies-futon-blonde-2639430/
# 29  /events/music/reinier-zonneveld-brennen-grey-2...
# 30         /events/music/sydney-wright-kelsi-2642106/
# 31                  /events/music/cienfuegos-2655711/

# %%
df.shape
# Out:
# (133, 4)

# %%
### code 
df = pd.DataFrame(columns=['artist', 'venue', 'time', 'link'])
for page in range(1,6):
    url = f'https://www.austinchronicle.com/events/music/2020-01-17/page-{page}/'
    res = requests.get(url)
    soup = BeautifulSoup(res.content)
    for i in soup.find_all(name='div', attrs={'class':'event-text'}):
        try:
            venue = i.find(name='div', attrs={'class':'venue'}).text
        except:
            venue = 'no venue'
        try:
            time = i.find(name='span',attrs={'class':'event-date'}).text
        except:
            time = 'no time'
        try:
            artist = i.find('h2').text
        except:
            artist = 'no artist'
        try:
            link = i.find('h2').find('a').attrs['href']
        except:
            link = 'no link'
        df.loc[len(df)] = [artist, venue, time, link]
    sleep(1)
